# %% [markdown]
# <a href="https://colab.research.google.com/github/sebassanchez5680-tech/Prueba/blob/main/Untitled23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("nice")
# Out:
# nice

# %%
print("ok")
# Out:
# ok
